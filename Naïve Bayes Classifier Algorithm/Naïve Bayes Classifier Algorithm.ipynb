# %% [markdown]
# # [Naïve Bayes Classifier Algorithm](https://www.javatpoint.com/machine-learning-naive-bayes-classifier)

# %%
import pandas as pd

Outlook = ['Rainy', 'Sunny', 'Overcast', 'Overcast', 'Sunny', 'Rainy', 'Sunny',
          'Overcast', 'Rainy', 'Sunny', 'Sunny', 'Rainy', 'Overcast', 'Overcast']

Play = ['Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes',
          'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes']

dataset = {
   'Outlook': Outlook,
   'Play':Play,
        }

arr = [i+1 for i in range(len(dataset['Outlook']))]
df = pd.DataFrame(dataset, index = arr)
df
# Out:
#      Outlook Play
# 1      Rainy  Yes
# 2      Sunny  Yes
# 3   Overcast  Yes
# 4   Overcast  Yes
# 5      Sunny   No
# 6      Rainy  Yes
# 7      Sunny  Yes
# 8   Overcast  Yes
# 9      Rainy   No
# 10     Sunny   No
# 11     Sunny  Yes
# 12     Rainy   No
# 13  Overcast  Yes
# 14  Overcast  Yes

# %%
df.to_csv('Weather Conditions.csv', header=False, index=False)

# %%
w = df.groupby('Outlook').size()
w
# Out:
# Outlook
# Overcast    5
# Rainy       4
# Sunny       5
# dtype: int64

# %%
w.sum()
# Out:
# 14

# %%
x = df.where(df['Play']=='Yes').groupby('Outlook').size()
x
# Out:
# Outlook
# Overcast    5
# Rainy       2
# Sunny       3
# dtype: int64

# %%
y = df.groupby('Play').size()
y
# Out:
# Play
# No      4
# Yes    10
# dtype: int64

# %%
z = df.where(df['Play']=='No').groupby('Outlook').size()
z
# Out:
# Outlook
# Rainy    2
# Sunny    2
# dtype: int64

# %% [markdown]
# # Applying Bayes'theorem:
#
# # p(y|s) = ( p(s|y) * p(y) ) / p(s)
#
# ![image.png](attachment:image.png)

# %%
psy = x[2]/x.sum()
psy
# Out:
# 0.3

# %%
ps = w[2]/w.sum()
ps
# Out:
# 0.35714285714285715

# %%
py = y[1]/y.sum()
py
# Out:
# 0.7142857142857143

# %%
pys = psy*py/ps
pys
# Out:
# 0.6

# %%
psn = z[1]/z.sum()
psn
# Out:
# 0.5

# %%
pn = y[0]/y.sum() 
pn
# Out:
# 0.2857142857142857

# %%
pns = psn*pn/ps
pns
# Out:
# 0.39999999999999997

# %%
if pys > pns:
    print('On a Sunny day, Player can play the game') 
else:
    print('On a Sunny day, Player can NOT... play the game')
# Out:
# On a Sunny day, Player can play the game
